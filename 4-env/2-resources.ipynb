# %% [markdown]
# # Managing the resources
#
# ## Project initialization
#
# Create a project: a dedicated space where we can manage functions, artifacts and executions.
#
# Use the ``username`` as param to create a personal project in the shared space.

# %%
import digitalhub as dh
import os

project = dh.get_or_create_project(f"{os.environ['USER']}-base")
project

# %% [markdown]
# ## 1. Create a dummy function
#
# We define a simple function for executing a stress program to utilize the resources.
#
# https://github.com/containerstack/alpine-stress

# %%
func = project.new_function(name="stress",
                            kind="container",
                            command="stress",
                            image="containerstack/alpine-stress"
                            )

# %% [markdown]
# Now we should be able to run it

# %%
run = func.run("job", args=["--cpu", "1", "--timeout", "10s"], local_execution=False, run_as_user="8877", wait=True)

# %% [markdown]
# Check the logs and the metrics from the console.

# %%
print(run.logs()[0]['content'])

# %% [markdown]
# ### 1.2 Require resources
#
# Change the params and use more than 2GB of ram. Does it work?

# %%
run = func.run("job", args=["--cpu", "1", "--timeout", "60s", "--vm-bytes", "4096M", "--vm", "2"], local_execution=False, run_as_user="8877", wait=True)

# %%
run.status

# %%
print(run.logs()[0]['content'])

# %% [markdown]
# Ask for the resources: 8GB of ram

# %%
run = func.run("job", args=["--cpu", "1", "--timeout", "60s", "--vm-bytes", "4096M", "--vm", "2"], resources={"cpu": 2, "mem": "8Gi"}, local_execution=False, run_as_user="8877", wait=True)

# %% [markdown]
# ### 1.3 Disk
#
# Try writing to disk.  By default `stress` writes 1Gb per writer

# %%
run = func.run("job", args=["--cpu", "1", "--timeout", "60s", "-d", "2"], resources={"cpu": 2, "mem": "8Gi"}, local_execution=False, run_as_user="8877", wait=True)

# %% [markdown]
# Check if it works. Add the scratch space.
#
# https://scc-digitalhub.github.io/sdk-docs/reference/configuration/kubernetes/overview/#ephemeral-volumes
